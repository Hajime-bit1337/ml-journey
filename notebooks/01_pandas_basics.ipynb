# %%
import pandas as pd
pd.__version__
# Out:
# '3.0.5'

# %%
Data = pd.DataFrame({
    'Name': ['Рома', 'Матвей', 'Дима', 'Ливес', 'Ксюша'],
    'Age': [18, 18, 18, 18, 18],
    'Money': [10000000, 10000, 3123, 999, 0],
    'City': ['Санкт-Петербург', 'Москва', 'Казань', 'Гамбург', 'Москва'],
    'IQ': [145, 55, 100, 122, 90]
})

iloc = Data.iloc[:3]
loc = Data.loc['City':'IQ']
mask = Data['Money'] > 0
group = Data.groupby('City')
sort = Data.sort_values('Money')
